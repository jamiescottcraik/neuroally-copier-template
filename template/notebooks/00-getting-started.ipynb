# %%
in{
 "cells": [
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "# Getting Started with {{ project_name }}\n",
    "\n",
    "> Generated on {{ generated_on }} with NeuroAlly.AI Scaffold\n",
    "\n",
    "Welcome! This notebook will walk you through your first steps using the {{ project_name }} scaffold. \n",
    "\n",
    "**What you’ll learn:**\n",
    "- Setup (environment, keys)\n",
    "- Running a provider example\n",
    "- How to extend/test\n"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "## 1. Environment Setup\n",
    "\n",
    "Make sure you have [Poetry](https://python-poetry.org/docs/#installation) and [Jupyter](https://jupyter.org/) installed.\n",
    "\n",
    "From your terminal:\n",
    "```bash\n",
    "poetry install\n",
    "poetry run jupyter notebook\n",
    "```\n",
    "\n",
    "If you use Conda, activate your environment first."
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "## 2. Configure API Keys\n",
    "\n",
    "Copy `.env.example` to `.env` and set the relevant keys for your chosen provider(s)."
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "# Load environment variables\n",
    "from dotenv import load_dotenv\n",
    "load_dotenv()"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "## 3. Try a Provider Example\n",
    "\n",
    "Replace the below import and usage according to your scaffold choices."
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "# Example: Test your provider\n",
    "from src.providers.{{ main_category }}.{{ (\n",
    "    llm_provider if main_category == \"llms\" else\n",
    "    vision_provider if main_category == \"vision\" else\n",
    "    speech_provider if main_category == \"speech\" else\n",
    "    generative_provider if main_category == \"generative\" else\n",
    "    nlp_provider if main_category == \"nlp\" else\n",
    "    ml_platform_provider if main_category == \"ml_platform\" else\n",
    "    \"\"\n",
    ") }}_provider import {{ (\n",
    "    llm_provider if main_category == \"llms\" else\n",
    "    vision_provider if main_category == \"vision\" else\n",
    "    speech_provider if main_category == \"speech\" else\n",
    "    generative_provider if main_category == \"generative\" else\n",
    "    nlp_provider if main_category == \"nlp\" else\n",
    "    ml_platform_provider if main_category == \"ml_platform\" else\n",
    "    \"\"\n",
    ")|capitalize }}Provider\n",
    "\n",
    "provider = {{ (\n",
    "    llm_provider if main_category == \"llms\" else\n",
    "    vision_provider if main_category == \"vision\" else\n",
    "    speech_provider if main_category == \"speech\" else\n",
    "    generative_provider if main_category == \"generative\" else\n",
    "    nlp_provider if main_category == \"nlp\" else\n",
    "    ml_platform_provider if main_category == \"ml_platform\" else\n",
    "    \"\"\n",
    ")|capitalize }}Provider()\n",
    "print(provider.example())"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "## 4. Next Steps\n",
    "- Explore the `src/providers/` directory\n",
    "- Add your own notebooks to try out ideas\n",
    "- See [CONTRIBUTING.md](../CONTRIBUTING.md) for style and PR tips\n"
   ]
  }
 ],
 "metadata": {
  "kernelspec": {
   "display_name": "Python 3",
   "language": "python",
   "name": "python3"
  },
  "language_info": {
   "name": "python",
   "version": "{{ python_version }}"
  }
 },
 "nbformat": 4,
 "nbformat_minor": 5
}
